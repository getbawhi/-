# %% [markdown]
# ## 모델 학습
#
# * 모델 학습 / 모델 검증 / 예측 등을 다룸
#
#     <텐서플로 2.0 공식 가이드에서 모델 학습에 권장하는 방법 두 가지></br>
#         1) 케라스 모델의 내장 API를 활용하는 방법
#         2) 학습, 검증, 예측 모든 과정을 GradientTape 객체를 활용해 직접 구현하는 방법
#
#             (1) 장점 : 메서드가 이미 구현 되어있어 간편하다
#             (2) 장점 : 좀 더 복잡한 로직을 유연하고 자유롭게 구현할 수 있다.
#             (2) 단점 : 일일이 구현해야 함

# %% [markdown]
# ### 내장 API를 활용하는 방법
#
# * 이미 정의된 케라스의 모델 객체가 있다고 가정해보자
# * 이 모델 객체는 케라스의 모델 객체이므로 여러 메서드가 이미 내장되어 있음
# * 따라서 내장 메서드를 간단히 사용하기만 하면 됨
#
#
# </br>
#
#     (1)  학습과정을 정의하기
#             - 학습 과정에서 사용 될 손실함수 (loss function), 옵티마이저 (optimizer), 평가에 사용 될 지표 (metric) 등 정의

# %%
# 1번 타입

import tensorflow as tf

model.compile(optimizer = tf.keras.optimizer.Adam(),
             loss = tf.keras.losses.CategoricalCrossentropy(),
             metrics = [tf.keras.metrics.Accuracy()])

# %%
# 2번 타입

model.compile(optimizer = 'adam',
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %% [markdown]
# * 이제 정의된 모델 객체를 대상으로
#     - 학습
#     - 평가
#     - 예측 메서드를 호출하면 학습이 진행됨
#
#     - 아래의 코드와 같이 fit 메서드를 호출하면 데이터들이 모델을 통과하며 학습이 진행된다.
#     - 또한, 학습이 진행되며 각 에폭당 모델의 성능(손실 함수, 정확도) 등이 출력됨을 볼 수 있다.

# %%
model.fit(x_train,y_train,
         batch_size = 64,
         epochs =3)

# %% [markdown]
# * 학습 과정에서 에폭마다 검증을 진행하는 것 또한 가능하다.
# * evaluate 메서드를 통해 검증 할 수 있지만 매번 에폭을 호출 해야 한다는 번거로움이 있다.
# * 따라서 에폭마다 검증 결과를 보기 위해 fit 함수에 검증 데이터를 추가로 넣으면 된다.

# %%
model.fit(x_train, y_train,
         batch_size = 64,
         epochs =3,
         validation_data=(x_val,y_val))

# %% [markdown]
# ### 더미 데이터를 활용한 감정 분석 모델링
#
# * 이번에 구현할 모델은 심층 신경망(Deep Neural Network) 구조를 사용한다
# * 텍스트의 긍정/부정을 예측하는 감정 분석(Sentiment Analysis) 모델
# </br></br>
#     - 각 단어로 구성된 입력값은 임베딩된 벡터로 변형된다.
#     - 이후 각 벡터를 평균해서 하나의 벡터로 만든다.
#     - 이후 하나의 은닉층을 거친 후 하나의 결괏값을 뽑는 구조이다.
#     - 마지막으로 나온 결괏값에 시그모이드 함수를 적용해 0과 1 사이의 값을 구한다.

# %% [markdown]
# ### Sequential 로 구현

# %%
import tensorflow as tf
from tensorflow.keras import preprocessing
from tensorflow import keras

layers = keras.layers

samples = ['너 오늘 이뻐 보인다',
          '나는 오늘 기분이 더러워',
          '끝내주는데, 좋은 일이 있나봐',
          '나 좋은 일이 생겼어',
          '아 오늘 진짜 짜증나',
          '환상적인데, 정말 좋은거 같아']

labels = [[1],[0],[1],[1],[0],[1]]

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(samples)
input_sequences = tokenizer.texts_to_sequences(samples)

word_index = tokenizer.word_index

## 전처리 과정 끝
## 모델 구축, 모델 학습에 필요한 변수 정의


batch_size = 2     
num_epochs = 100
vocab_size =len(word_index)+1
emb_size = 128
hidden_dimension = 256
output_dimension = 1

# Sequential API를 활용해 심층 신경망 모델을 생성할 것임


model = tf.keras.Sequential()
model.add(layers.Embedding(vocab_size, emb_size, input_length = 4))
model.add(layers.Lambda(lambda x: tf.reduce_mean(x, axis = 1)))
model.add(layers.Dense(hidden_dimension, activation ='relu'))
model.add(layers.Dense(output_dimension, activation = 'sigmoid'))

# 입력값을 임베딩하는 Embedding 층을 모델에 추가했다 
# 임베딩 된 각 단어의 벡터를 평균하기 위해 람다(Lamda)층을 사용한다
# lamda층은 텐서플로 연산을 Sequential API 와 Functional API에 적용하기 위해 사용하는 방법임
# 평균의 경우 , 하나의 층으로 정의돼 있지 않기 때문에 람다 층을 활용, 해당 층에 들어오는 입력값들을 평균함
# 평균을 낸 후 은닉층을 통과한 후 최종 출력값을 뽑기 위해 두개의 Dense 층을 모델에 추가

# 최종 출력값을 뽑은 Dense 층과 경우 0과 1 사이의 확률값을 뽑기위해 시그모이드 함수 정의


model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# 모델을 컴파일하는 메서드를 통해 학습과정을 정의
# 옵티마이저 : Adam 최적화 알고리즘 사용
# 이진 교차 엔트로피 손실함수 (binary cross-entropy) : 이진 분류 문제이므로
# accuracy : 가장 널리 사용되는 정확도

model.fit(input_sequences, labels, epochs=num_epochs, batch_size = batch_size)
# Out:
# 2023-03-26 13:18:52.791759: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5000
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6597 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6422 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6239 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5783 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5497 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 1.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3433 - accuracy: 1.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2958 - accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2038 - accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1650 - accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1300 - accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 30/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 34/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.7415e-04 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.4316e-04 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.1863e-04 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.9135e-04 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.6584e-04 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.4082e-04 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 1ms/step - loss: 8.2090e-04 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.9446e-04 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.7628e-04 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.5459e-04 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.3675e-04 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.1699e-04 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.9876e-04 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.8238e-04 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.6638e-04 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.4971e-04 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.3502e-04 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.1830e-04 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.0471e-04 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.9044e-04 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.7593e-04 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 3ms/step - loss: 5.6307e-04 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.5128e-04 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.3795e-04 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.2676e-04 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.1537e-04 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.0320e-04 - accuracy: 1.0000

# %% [markdown]
# ### Functional API 로 구현

# %%
import tensorflow as tf
from tensorflow.keras import preprocessing

layers = keras.layers

samples = ['너 오늘 이뻐 보인다',
          '나는 오늘 기분이 더러워',
          '끝내주는데, 좋은 일이 있나봐',
          '나 좋은 일이 생겼어',
          '아 오늘 진짜 짜증나',
          '환상적인데, 정말 좋은거 같아']

labels = [[1],[0],[1],[1],[0],[1]]

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(samples)
input_sequences = tokenizer.texts_to_sequences(samples)

word_index = tokenizer.word_index



emb_size = 128
vocab_size = len(word_index)+1



inputs = layers.Input(shape=(4,))
embed_output = layers.Embedding(vocab_size, emb_size)(inputs)
pooled_output = tf.reduce_mean(embed_output, axis = 1)
hidden_layer = layers.Dense(hidden_dimension, activation = 'relu')(pooled_output)
outputs = layers.Dense(output_dimension, activation ='sigmoid')(hidden_layer)
model = tf.keras.Model(inputs = inputs, outputs = outputs)

model.compile(optimizer =tf.keras.optimizers.Adam(0.001),
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])
model.fit(input_sequences, labels, epochs=num_epochs, batch_size = batch_size)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.8333
# Epoch 2/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6714 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6545 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6375 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6156 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5942 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5635 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5288 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 1.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2972 - accuracy: 1.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1664 - accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1347 - accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 34/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 998us/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.9598e-04 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.6725e-04 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.3921e-04 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.1325e-04 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 1ms/step - loss: 8.9059e-04 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 1ms/step - loss: 8.6231e-04 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.4094e-04 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.1563e-04 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.9640e-04 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.7563e-04 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.5674e-04 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.3704e-04 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.1907e-04 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.0008e-04 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.8518e-04 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.6744e-04 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.5083e-04 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.3588e-04 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.2097e-04 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.0688e-04 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.9415e-04 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.8132e-04 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.6786e-04 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.5451e-04 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.4145e-04 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.3047e-04 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.1805e-04 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.0886e-04 - accuracy: 1.0000

# %% [markdown]
# ### Subclassing 방법으로 구현

# %%
import tensorflow as tf
from tensorflow.keras import preprocessing

layers = keras.layers

samples = ['너 오늘 이뻐 보인다',
          '나는 오늘 기분이 더러워',
          '끝내주는데, 좋은 일이 있나봐',
          '나 좋은 일이 생겼어',
          '아 오늘 진짜 짜증나',
          '환상적인데, 정말 좋은거 같아']

labels = [[1],[0],[1],[1],[0],[1]]

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(samples)
input_sequences = tokenizer.texts_to_sequences(samples)

word_index = tokenizer.word_index





emb_size = 128
vocab_size = len(word_index)+1

class CustomModel(tf.keras.Model):
    
    def __init__(self, vocab_size, embed_dimension, hidden_dimension, output_dimension):
        super(CustomModel, self).__init__(name='my_model')
        self.embedding = layers.Embedding(vocab_size, embed_dimension)
        self.dense_layer = layers.Dense(hidden_dimension, activation ='relu')
        self.output_layer = layers.Dense(output_dimension, activation = 'sigmoid')
        
    def call(self, inputs):
        x = self.embedding(inputs)
        x = tf.reduce_mean(x, axis=1)
        x = self.dense_layer(x)
        x = self.output_layer(x)
        
        
        return x
    
    
model = CustomModel(vocab_size = vocab_size,
                   embed_dimension=emb_size,
                   hidden_dimension = hidden_dimension,
                   output_dimension = output_dimension)

model.compile(optimizer = tf.keras.optimizers.Adam(0.001),
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

model.fit(input_sequences, labels, epochs=num_epochs, batch_size = batch_size)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6969 - accuracy: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6780 - accuracy: 0.8333
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6631 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6473 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6309 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5923 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4611 - accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4202 - accuracy: 1.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3721 - accuracy: 1.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3231 - accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2292 - accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1883 - accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1205 - accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0597 - accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 25/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.7363e-04 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.5387e-04 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 1ms/step - loss: 9.2254e-04 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.0135e-04 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.7620e-04 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.5148e-04 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 1ms/step - loss: 8.2882e-04 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 8.0887e-04 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.8944e-04 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.6925e-04 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 1ms/step - loss: 7.4950e-04 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.3139e-04 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 7.1364e-04 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.9710e-04 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.8054e-04 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.6676e-04 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.5005e-04 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.3658e-04 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 6.2088e-04 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 1ms/step - loss: 6.0780e-04 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 1ms/step - loss: 5.9279e-04 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.8100e-04 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.7073e-04 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.5662e-04 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 5.4505e-04 - accuracy: 1.0000
